# %% [markdown]
# <a href="https://colab.research.google.com/github/sqltrainme/Vman/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd



df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)
df
# Out:
#                                School Name  ... Percent Scoring CR
# School DBN                                  ...
# 01M034      P.S. 034 Franklin D. Roosevelt  ...                 na
# 01M034      P.S. 034 Franklin D. Roosevelt  ...                 na
# 01M034      P.S. 034 Franklin D. Roosevelt  ...                 na
# 01M140              P.S. 140 Nathan Straus  ...                 na
# 01M140              P.S. 140 Nathan Straus  ...                 na
# ...                                    ...  ...                ...
# 84X717                Icahn Charter School  ...                 na
# 84X717                Icahn Charter School  ...                 na
# 84X717                Icahn Charter School  ...                 na
# 84X717                Icahn Charter School  ...                 na
# 84X717                Icahn Charter School  ...                 na
#
# [212331 rows x 14 columns]

# %%
import pandas as pd



df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)
df


df.min()
# Out:
# School Name                    47 The American Sign Language and English Seco...
# School Level                                                          Elementary
# Year                                                                        2015
# Total Tested                                                                   1
# Mean Score                                                                    15
# Number Scoring Below 65                                                        0
# Percent Scoring Below 65                                                       0
# Number Scoring 65 or Above                                                     0
# Percent Scoring 65 or Above                                                    0
# Number Scoring 80 or Above                                                     0
# Percent Scoring 80 or Above                                                    0
# Number Scoring CR                                                              0
# ...

# %%
import pandas as pd



df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)
df


df.max()
# Out:
# School Name                    Young Women's Leadership School, Queens
# School Level                                          Secondary School
# Year                                                              2017
# Total Tested                                                      1729
# Mean Score                                                           s
# Number Scoring Below 65                                              s
# Percent Scoring Below 65                                             s
# Number Scoring 65 or Above                                           s
# Percent Scoring 65 or Above                                          s
# Number Scoring 80 or Above                                           s
# Percent Scoring 80 or Above                                          s
# Number Scoring CR                                                   na
# Percent Scoring CR                                                  na
# dtype: object

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline



df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)
df


df.head()

df.groupby(['School Name'])['Mean Score'].count()
# Out:
# School Name
# 47 The American Sign Language and English Secondar    356
# A. Philip Randolph Campus High School                 459
# ACORN Community High School                           364
# Abraham Lincoln High School                           480
# Abraham Lincoln Yabc                                  248
#                                                      ...
# Young Women's Leadership School                       378
# Young Women's Leadership School of Brooklyn           337
# Young Women's Leadership School of the Bronx          142
# Young Women's Leadership School, Astoria              338
# Young Women's Leadership School, Queens               391
# Name: Mean Score, Length: 1012, dtype: int64

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline



df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)
df


df.head()

df[df['School Name'] == 'Hillcrest'].count()
# Out:
# School Name                    0
# School Level                   0
# Regents Exam                   0
# Year                           0
# Total Tested                   0
# Mean Score                     0
# Number Scoring Below 65        0
# Percent Scoring Below 65       0
# Number Scoring 65 or Above     0
# Percent Scoring 65 or Above    0
# Number Scoring 80 or Above     0
# Percent Scoring 80 or Above    0
# Number Scoring CR              0
# Percent Scoring CR             0
# dtype: int64

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline



df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)
df


df.head()

df[df['School Name'].str.contains('Hillcrest')]
# Out:
#                       School Name  ... Percent Scoring CR
# School DBN                         ...
# 28Q505      Hillcrest High School  ...               12.9
# 28Q505      Hillcrest High School  ...               13.2
# 28Q505      Hillcrest High School  ...                8.8
# 28Q505      Hillcrest High School  ...               12.4
# 28Q505      Hillcrest High School  ...               36.7
# ...                           ...  ...                ...
# 28Q505      Hillcrest High School  ...                 na
# 28Q505      Hillcrest High School  ...                 na
# 28Q505      Hillcrest High School  ...                 na
# 28Q505      Hillcrest High School  ...                 na
# 28Q505      Hillcrest High School  ...                 na
#
# [473 rows x 14 columns]

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline



df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)
df


df.head()

df[df['School Name'].str.contains('Hillcrest')]
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3978737450>,
# ...
#       dtype=object)

# %%
The above is showing a histogram of Total scores per year and amount tested. It is incorrect due to various data mixing.

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline



df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)
df


df.head()

df[df['School Name'].str.contains('Hillcrest')]
df.hist()
df.plot()

# %%
The above includes a Plot chart with the bottom axis rep various schools aka a codes matched to total amount of students tested.

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns




df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)
df





df.head()
df[['School Name','Mean Score']]

df[df['School Name'].str.contains ('Hillcrest')]
# Out:
#                       School Name  ... Percent Scoring CR
# School DBN                         ...
# 28Q505      Hillcrest High School  ...               12.9
# 28Q505      Hillcrest High School  ...               13.2
# 28Q505      Hillcrest High School  ...                8.8
# 28Q505      Hillcrest High School  ...               12.4
# 28Q505      Hillcrest High School  ...               36.7
# ...                           ...  ...                ...
# 28Q505      Hillcrest High School  ...                 na
# 28Q505      Hillcrest High School  ...                 na
# 28Q505      Hillcrest High School  ...                 na
# 28Q505      Hillcrest High School  ...                 na
# 28Q505      Hillcrest High School  ...                 na
#
# [473 rows x 14 columns]

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns




df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)
df





df.head()
df[['School Name','Mean Score']]

df[['Regents Exam','Mean Score']]
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3967162c50>,
# ...
#       dtype=object)

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns




df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv',index_col=0)
df
sns.displot('Year')
