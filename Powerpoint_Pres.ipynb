# %% [markdown]
# <a href="https://colab.research.google.com/github/sqltrainme/Vman/blob/main/Powerpoint_Pres.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import numpy as np

import matplotlib

import seaborn as sns
# %matplotlib inline

df = pd.read_csv('https://data.cityofnewyork.us/resource/kpav-sd4t.csv',index_col=0)
df
# Out:
#                                 agency  ...             process_date
# job_id                                  ...
# 460319        DEPARTMENT OF SANITATION  ...  2021-08-03T00:00:00.000
# 242091   DEPT OF HEALTH/MENTAL HYGIENE  ...  2021-08-03T00:00:00.000
# 379094    NYC EMPLOYEES RETIREMENT SYS  ...  2021-08-03T00:00:00.000
# 462332  DEPT OF ENVIRONMENT PROTECTION  ...  2021-08-03T00:00:00.000
# 462638     TAXI & LIMOUSINE COMMISSION  ...  2021-08-03T00:00:00.000
# ...                                ...  ...                      ...
# 467075   OFFICE OF MANAGEMENT & BUDGET  ...  2021-08-03T00:00:00.000
# 133921           NYC HOUSING AUTHORITY  ...  2021-08-03T00:00:00.000
# 445946  DEPT OF ENVIRONMENT PROTECTION  ...  2021-08-03T00:00:00.000
# 470974           NYC FIRE PENSION FUND  ...  2021-08-03T00:00:00.000
# 463858   DEPT OF YOUTH & COMM DEV SRVS  ...  2021-08-03T00:00:00.000
#
# [1000 rows x 29 columns]

# %%
df = pd.read_csv('https://data.cityofnewyork.us/resource/kpav-sd4t.csv',index_col=0)
df

list(df.columns)
# Out:
# ['agency',
#  'posting_type',
#  'number_of_positions',
#  'business_title',
#  'civil_service_title',
#  'title_classification',
#  'title_code_no',
#  'level',
#  'job_category',
#  'full_time_part_time_indicator',
#  'career_level',
#  'salary_range_from',
#  'salary_range_to',
#  'salary_frequency',
#  'work_location',
#  'division_work_unit',
#  'job_description',
#  'minimum_qual_requirements',
#  'preferred_skills',
#  'additional_information',
#  'to_apply',
#  'hours_shift',
#  'work_location_1',
#  'recruitment_contact',
#  'residency_requirement',
#  'posting_date',
#  'post_until',
#  'posting_updated',
#  'process_date']

# %%
df = pd.read_csv('https://data.cityofnewyork.us/resource/kpav-sd4t.csv',index_col=0)
df

df.agency
# Out:
# job_id
# 460319          DEPARTMENT OF SANITATION
# 242091     DEPT OF HEALTH/MENTAL HYGIENE
# 379094      NYC EMPLOYEES RETIREMENT SYS
# 462332    DEPT OF ENVIRONMENT PROTECTION
# 462638       TAXI & LIMOUSINE COMMISSION
#                        ...
# 467075     OFFICE OF MANAGEMENT & BUDGET
# 133921             NYC HOUSING AUTHORITY
# 445946    DEPT OF ENVIRONMENT PROTECTION
# 470974             NYC FIRE PENSION FUND
# 463858     DEPT OF YOUTH & COMM DEV SRVS
# Name: agency, Length: 1000, dtype: object

# %%
df.career_level
# Out:
# job_id
# 460319    Experienced (non-manager)
# 242091    Experienced (non-manager)
# 379094    Experienced (non-manager)
# 462332                  Entry-Level
# 462638                      Student
#                     ...
# 467075                  Entry-Level
# 133921                  Entry-Level
# 445946    Experienced (non-manager)
# 470974    Experienced (non-manager)
# 463858    Experienced (non-manager)
# Name: career_level, Length: 1000, dtype: object

# %%
df.career_level.value_counts().Student
# Out:
# 29

# %%
df.career_level.value_counts()
# Out:
# Experienced (non-manager)    593
# Entry-Level                  219
# Manager                      136
# Student                       29
# Executive                     23
# Name: career_level, dtype: int64

# %%
df = pd.read_csv('https://data.cityofnewyork.us/resource/kpav-sd4t.csv',index_col=0)
df

df.drop(columns=['title_code_no','level','full_time_part_time_indicator','additional_information','to_apply','hours_shift','work_location_1','recruitment_contact', 'residency_requirement','posting_date','post_until','posting_updated','process_date'],axis=1)
# Out:
#                                 agency  ...                                   preferred_skills
# job_id                                  ...
# 460319        DEPARTMENT OF SANITATION  ...  â¢\tBasic computer skills, such as using Elec...
# 242091   DEPT OF HEALTH/MENTAL HYGIENE  ...  Excellent interpersonal, communication and pre...
# 379094    NYC EMPLOYEES RETIREMENT SYS  ...  Â·\tExperience with testing /deployment tools ...
# 462332  DEPT OF ENVIRONMENT PROTECTION  ...  -Excellent supervisory skills -Good communicat...
# 462638     TAXI & LIMOUSINE COMMISSION  ...  Strong computer skills, with significant Excel...
# ...                                ...  ...                                                ...
# 467075   OFFICE OF MANAGEMENT & BUDGET  ...  DESIRED SKILLS:  â¢\tStrong computer skills i...
# 133921           NYC HOUSING AUTHORITY  ...                                                NaN
# ...

# %%
df = pd.read_csv('https://data.cityofnewyork.us/resource/kpav-sd4t.csv',index_col=0)
df

df[df['career_level']=='Entry-Level']
# Out:
#                                 agency  ...             process_date
# job_id                                  ...
# 462332  DEPT OF ENVIRONMENT PROTECTION  ...  2021-08-03T00:00:00.000
# 461876      DEPT OF PARKS & RECREATION  ...  2021-08-03T00:00:00.000
# 461876      DEPT OF PARKS & RECREATION  ...  2021-08-03T00:00:00.000
# 466540               POLICE DEPARTMENT  ...  2021-08-03T00:00:00.000
# 465591  DEPT OF ENVIRONMENT PROTECTION  ...  2021-08-03T00:00:00.000
# ...                                ...  ...                      ...
# 469175    DEPARTMENT OF BUSINESS SERV.  ...  2021-08-03T00:00:00.000
# 463568      DEPT OF PARKS & RECREATION  ...  2021-08-03T00:00:00.000
# 468791  HOUSING PRESERVATION & DVLPMNT  ...  2021-08-03T00:00:00.000
# 467075   OFFICE OF MANAGEMENT & BUDGET  ...  2021-08-03T00:00:00.000
# 133921           NYC HOUSING AUTHORITY  ...  2021-08-03T00:00:00.000
#
# [219 rows x 29 columns]

# %%
df = pd.read_csv('https://data.cityofnewyork.us/resource/kpav-sd4t.csv',usecols=['career_level'])
df

df[df['career_level']=='Entry-Level']

df.describe()
# Out:
#                      career_level
# count                        1000
# unique                          5
# top     Experienced (non-manager)
# freq                          593

# %%
sns.histplot(df,x='career_level')

# %%
print(219/1000)
# Out:
# 0.219
